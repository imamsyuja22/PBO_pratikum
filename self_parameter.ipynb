# %% [markdown]
# <a href="https://colab.research.google.com/github/imamsyuja22/PBO_pratikum/blob/main/self_parameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ikan:
    species = "air tawar"  # Class attribute

    def __init__(self, name, color):
        self.name = name  # Instance attribute
        self.color = color  # Instance attribute

ikan1 = ikan("patin", "white")  # Create an instance of Dog
ikan2 = ikan("gurami", "black")  # Create another instance of Dog

print(ikan1.name, ikan1.color, ikan1.species)  # Access instance and class attributes
print(ikan2.name, ikan2.color, ikan2.species)  # Access instance and class attributes
print(ikan.species)  # Access class attribute directly
# Out:
# patin white air tawar
# gurami black air tawar
# air tawar
