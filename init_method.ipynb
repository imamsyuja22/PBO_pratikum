# %% [markdown]
# <a href="https://colab.research.google.com/github/imamsyuja22/PBO_pratikum/blob/main/init_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ikan:
  jenis = "air tawar"

  def __init__(self, nama, umur):
    self.nama = nama
    self.umur = umur

ikan1 = ikan("lele", 3)
print(ikan1.umur)
# Out:
# 3
