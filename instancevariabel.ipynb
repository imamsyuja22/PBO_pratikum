# %% [markdown]
# <a href="https://colab.research.google.com/github/imamsyuja22/PBO_pratikum/blob/main/instancevariabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ikan:
  jenis = "air tawar"

  def __init__(self, nama, umur):
    self.nama = nama
    self.umur = umur

ikan1 = ikan("nila", 4)
ikan2 = ikan("bawal", 5)

print(ikan1.nama)
print(ikan.jenis)

ikan1.nama = "patin"
print(ikan1.nama)

ikan2.nama = "lele"
print(ikan2.nama)

ikan.jenis = "air laut"
print(ikan1.jenis)
print(ikan2.jenis)
# Out:
# nila
# air tawar
# patin
# lele
# air laut
# air laut
